# %% [markdown]
# # XGBoost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

from warnings import filterwarnings
filterwarnings('ignore')

# %%
diabetes = pd.read_csv("diabetes.csv")
df = diabetes.copy()
df = df.dropna()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df["Outcome"]
X = df.drop(['Outcome'], axis=1)
X = pd.DataFrame(X)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.30,
                                                    random_state=42)

# %%
xgb_model = XGBClassifier().fit(X_train, y_train)

# %%
y_pred = xgb_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7359307359307359

# %% [markdown]
# ## Model Tuning

# %%
xgb_params = {
        'n_estimators': [100, 500, 1000, 2000],
        'subsample': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5,6],
        'learning_rate': [0.1,0.01,0.02,0.05],
        "min_samples_split": [2,5,10]}

# %%
xgb = XGBClassifier()

xgb_cv_model = GridSearchCV(xgb, xgb_params, cv = 10, n_jobs = -1, verbose = 2)

# %%
xgb_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.6s
# [12:11:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.2s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.9s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   1.0s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.6s
# [12:11:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.2s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   1.2s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.9s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.6s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   1.1s
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.2s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.4s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.8s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:11:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.3s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   1.3s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   1.0s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.6s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.6s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   1.1s
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.3s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:11:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.4s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:11:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.3s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   1.0s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   1.0s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   1.1s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.6s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   1.1s
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.4s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.3s
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   1.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.6s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   1.1s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   1.0s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   1.0s
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   1.2s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:11:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.4s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:11:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:11:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:11:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.5s
# [12:12:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   1.5s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.6s
# [12:12:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.6s
# [12:12:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   1.1s
# [12:12:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   1.2s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.6s
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.7s
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.3s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:12:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# ...
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.5s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:17:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.5s
# [12:17:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:17:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:17:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.8s
# [12:17:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.4s
# [12:17:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.3s
# [12:17:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   1.5s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.5s
# [12:17:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:17:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.7s
# [12:17:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:17:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.8s
# [12:17:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:17:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   1.4s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:17:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.5s
# [12:17:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.6s
# [12:17:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.2s
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:16:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.4s
# [12:16:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:16:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.9s
# [12:16:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.8s
# [12:16:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:16:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   1.4s
# [12:16:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   1.4s
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.4s
# [12:17:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:17:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.8s
# [12:17:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:17:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.8s
# [12:17:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   1.3s
# [12:17:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   1.4s
# [12:17:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [12:17:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.5s
# [12:17:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.5s
# [12:17:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:17:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:17:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.8s
# [12:17:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   1.4s
# [12:17:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   1.4s
# [12:17:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   1.4s
# [12:17:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.6s
# [12:17:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.5s
# [12:17:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.8s
# [12:17:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.8s
# [12:17:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.02, 0.05],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 500, 1000, 2000],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=2)

# %%
xgb_cv_model.best_params_
# Out:
# {'learning_rate': 0.02,
#  'max_depth': 3,
#  'min_samples_split': 2,
#  'n_estimators': 100,
#  'subsample': 0.6}

# %%
xgb = XGBClassifier(learning_rate = 0.02,
                    max_depth = 3,
                    min_samples_split = 2,
                    n_estimators = 100,
                    subsample = 0.6)

# %%
xgb_tuned =  xgb.fit(X_train,y_train)
# Out:
# [12:17:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.

# %%
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7575757575757576
