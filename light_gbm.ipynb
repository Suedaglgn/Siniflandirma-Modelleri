# %% [markdown]
# # LightGBM

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from lightgbm import LGBMClassifier

from warnings import filterwarnings
filterwarnings('ignore')

# %%
diabetes = pd.read_csv("diabetes.csv")
df = diabetes.copy()
df = df.dropna()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df["Outcome"]
X = df.drop(['Outcome'], axis=1)
X = pd.DataFrame(X)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.30,
                                                    random_state=42)

# %%
lgbm_model = LGBMClassifier().fit(X_train, y_train)

# %%
y_pred = lgbm_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7229437229437229

# %%
lgbm_params = {
        'n_estimators': [100, 500, 1000, 2000],
        'subsample': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5,6],
        'learning_rate': [0.1,0.01,0.02,0.05],
        "min_child_samples": [5,10,20]}

# %%
lgbm = LGBMClassifier()

lgbm_cv_model = GridSearchCV(lgbm, lgbm_params,
                             cv = 10,
                             n_jobs = -1,
                             verbose = 2)

# %%
lgbm_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=1.0; total time=   0.3s
# ...
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=500, subsample=1.0; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=4, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=1000, subsample=1.0; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=1000, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=1000, subsample=1.0; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=5, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=2000, subsample=0.6; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=10, n_estimators=2000, subsample=1.0; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=1000, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=6, min_child_samples=20, n_estimators=2000, subsample=0.6; total time=   0.7s
# GridSearchCV(cv=10, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.02, 0.05],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_child_samples': [5, 10, 20],
#                          'n_estimators': [100, 500, 1000, 2000],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=2)

# %%
lgbm_cv_model.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_samples': 20,
#  'n_estimators': 100,
#  'subsample': 0.6}

# %%
lgbm = LGBMClassifier(learning_rate = 0.05,
                       max_depth = 3,
                       subsample = 0.6,
                       n_estimators = 100,
                       min_child_samples = 20)

# %%
lgbm_tuned = lgbm.fit(X_train,y_train)

# %%
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7489177489177489
